# %%
from src.generator import main
out = main()
# Out:
# Parameters
# Done
# Clock
# Done
# Generators
# Done
# initialise Time Generators
# Done
# Create callers
# Done
# Added atributes
# Creating social network
# Done
# Done SNA
# Mobility
# Network created
# Agent relationship created
# Done all customers
# Creating circus
# Done
# Start run

# %%
out[0].get_contents()[1]["customers"]._transient_attributes["MAIN_ACCT"]._table
# Out:
#             activity  clock   value
# 0000000000       1.0     -9  1990.0
# 0000000001       1.0    -10  1240.0
# 0000000002       1.0     -7  1797.0
# 0000000003       1.0     -2  1728.0
# 0000000004       1.0     -7  1773.0
# 0000000005       1.0     -7  1765.0
# 0000000006       1.0    -11   980.0
# 0000000007       1.0     -8  1143.0
# 0000000008       1.0     -9  1879.0
# 0000000009       1.0     -6  1757.0
# 0000000010       1.0    -11   990.0
# 0000000011       1.0     -6  1990.0
# 0000000012       1.0    -11   948.0
# 0000000013       1.0     -8  1571.0
# 0000000014       1.0     -8  1841.0
# 0000000015       1.0     -7  1806.0
# 0000000016       1.0     -8  1735.0
# 0000000017       1.0     -6  1567.0
# 0000000018       1.0     -6  1783.0
# 0000000019       1.0    -11   990.0
# 0000000020       1.0     -5  1742.0
# 0000000021       1.0     -8  1828.0
# 0000000022       1.0     -9  1970.0
# 0000000023       1.0     -6  1771.0
# 0000000024       1.0     -6  1644.0
# ...

# %%
out[1]

# %%
out[2]

# %%
out[3]
# Out:
#              A      AGENT  VALUE           datetime CUSTOMER_NUMBER       CELL
# 0   0000000001  AGENT_034   1000  08062016 00:36:24   0032478242305  CELL_0030
# 1   0000000029  AGENT_024   1000  08062016 00:41:46   0032475314390  CELL_0039
# 2   0000000052  AGENT_040   1000  08062016 00:21:30   0032479896864  CELL_0034
# 3   0000000086  AGENT_013   1000  08062016 00:55:40   0032477423637  CELL_0031
# 4   0000000087  AGENT_060   1000  08062016 00:43:00   0032476652753  CELL_0058
# 5   0000000093  AGENT_063   1000  08062016 00:16:43   0032478242348  CELL_0087
# 6   0000000095  AGENT_073   1000  08062016 00:05:03   0032478280902  CELL_0063
# 7   0000000000  AGENT_016   1000  08062016 01:28:23   0032478721241  CELL_0037
# 8   0000000008  AGENT_047   1000  08062016 01:07:24   0032476504058  CELL_0019
# 9   0000000022  AGENT_092   1000  08062016 01:14:26   0032477442558  CELL_0032
# 10  0000000025  AGENT_077   1000  08062016 01:51:30   0032478183739  CELL_0045
# ...

# %%
from src.util_functions import assign_random_proportions

x = assign_random_proportions("A","Product",range(10),range(2),123456)

# %%
x
