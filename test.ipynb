# %%
from src.generator import main
out = main()
# Out:
# Parameters
# Done
# Clock
# Done
# Generators
# Done
# initialise Time Generators
# Done
# Create callers
# Done
# Added atributes
# Creating social network
# Done
# Done SNA
# Mobility
# Network created
# Done all customers
# Creating circus
# Done
# Start run

# %%
out[0].get_contents()[1]["customers"]._transient_attributes["CELL"]._table
# Out:
#             activity  clock      value
# 0000000000       1.0     13  CELL_0010
# 0000000001       1.0     12  CELL_0014
# 0000000002       1.0     23  CELL_0099
# 0000000003       1.0      9  CELL_0064
# 0000000004       1.0      9  CELL_0091
# 0000000005       1.0     15  CELL_0040
# 0000000006       1.0      0  CELL_0015
# 0000000007       1.0      8  CELL_0045
# 0000000008       1.0      7  CELL_0010
# 0000000009       1.0      4  CELL_0093
# 0000000010       1.0     17  CELL_0069
# 0000000011       1.0      0  CELL_0099
# 0000000012       1.0      8  CELL_0010
# 0000000013       1.0      9  CELL_0051
# 0000000014       1.0      8  CELL_0046
# 0000000015       1.0     17  CELL_0094
# 0000000016       1.0     17  CELL_0099
# 0000000017       1.0      8  CELL_0097
# 0000000018       1.0      7  CELL_0066
# 0000000019       1.0      7  CELL_0099
# 0000000020       1.0      9  CELL_0054
# 0000000021       1.0     17  CELL_0095
# 0000000022       1.0     11  CELL_0015
# ...

# %%
out[1]
# Out:
#                 A           B  PASS_CONDITIONS           datetime  \
# 0      0000000001  0000008028                1  08062016 00:35:13
# 1      0000000025  0000003692                1  08062016 00:46:34
# 2      0000000029  0000006668                1  08062016 00:08:18
# 3      0000000031  0000001405                1  08062016 00:52:01
# 4      0000000052  0000005653                1  08062016 00:02:51
# 5      0000000086  0000002315                1  08062016 00:46:39
# 6      0000000087  0000008202                1  08062016 00:09:15
# 7      0000000091  0000005439                1  08062016 00:48:27
# 8      0000000093  0000007084                1  08062016 00:00:32
# 9      0000000095  0000003528                1  08062016 00:03:35
# 10     0000000100  0000001107                1  08062016 00:11:16
# 11     0000000101  0000009713                1  08062016 00:36:24
# 12     0000000111  0000006055                1  08062016 00:41:46
# ...

# %%
out[2]
# Out:
#                A        new           datetime
# 0     0000000052  CELL_0021  08062016 00:42:08
# 1     0000000205  CELL_0095  08062016 00:39:03
# 2     0000000213  CELL_0042  08062016 00:10:23
# 3     0000000230  CELL_0093  08062016 00:50:46
# 4     0000000302  CELL_0024  08062016 00:11:23
# 5     0000000572  CELL_0036  08062016 00:20:05
# 6     0000000583  CELL_0067  08062016 00:19:59
# 7     0000000792  CELL_0076  08062016 00:00:07
# 8     0000000814  CELL_0007  08062016 00:08:07
# 9     0000000960  CELL_0061  08062016 00:42:45
# 10    0000001105  CELL_0038  08062016 00:28:33
# 11    0000001128  CELL_0029  08062016 00:17:12
# 12    0000001159  CELL_0012  08062016 00:24:00
# 13    0000001280  CELL_0075  08062016 00:57:00
# 14    0000001289  CELL_0095  08062016 00:10:19
# 15    0000001370  CELL_0030  08062016 00:40:16
# 16    0000001410  CELL_0015  08062016 00:00:55
# 17    0000001458  CELL_0070  08062016 00:51:36
# 18    0000001466  CELL_0041  08062016 00:17:07
# ...

# %%
out[3]
# Out:
# {'caller SNA graph creation': 0.3999999999999999,
#  'caller attribute creation': 1.4100000000000001,
#  'caller creation (solo)': 0.020000000000000018,
#  'callers creation (full)': 1.8599999999999999,
#  'circus creation': 0.0,
#  'clocks': 0.0,
#  'generators': 0.050000000000000044,
#  'init generators': 0.0,
#  'mobility attribute creation': 0.040000000000000036,
#  'mobility graph creation': 1.5099999999999998,
#  'one run (average)': 1.723,
#  'parameters': 0.0,
#  'runs (all)': 17.23}
