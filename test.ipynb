# %%
from src.generator import main
out = main()
# Out:
# Parameters
# Done
# Clock
# Done
# Generators
# Done
# initialise Time Generators
# Done
# Create callers
# Done
# Added atributes
# Mobility
# Network created
# Done all customers
# Creating circus
# Done
# Start run
# iteration 0 on 600
# iteration 1 on 600
# iteration 2 on 600
# iteration 3 on 600
# iteration 4 on 600
# iteration 5 on 600
# iteration 6 on 600
# iteration 7 on 600
# iteration 8 on 600
# iteration 9 on 600
# iteration 10 on 600
# iteration 11 on 600
# iteration 12 on 600
# iteration 13 on 600
# iteration 14 on 600
# iteration 15 on 600
# iteration 16 on 600
# iteration 17 on 600
# iteration 18 on 600
# iteration 19 on 600
# iteration 20 on 600
# iteration 21 on 600
# iteration 22 on 600
# iteration 23 on 600
# iteration 24 on 600
# iteration 25 on 600
# iteration 26 on 600
# iteration 27 on 600
# iteration 28 on 600
# iteration 29 on 600
# iteration 30 on 600
# iteration 31 on 600
# iteration 32 on 600
# iteration 33 on 600
# iteration 34 on 600
# ...

# %%
out[0].get_contents()[1]["customers"]._transient_attributes["SIM"].stock()._table
# Out:
#          AGENT        ITEM
# 0    AGENT_213  SIM_465053
# 1    AGENT_572  SIM_304180
# 2    AGENT_302  SIM_015877
# 3    AGENT_960  SIM_362661
# 4    AGENT_205  SIM_277356
# 5    AGENT_157  SIM_051688
# 6    AGENT_583  SIM_294460
# 7    AGENT_644  SIM_415582
# 8    AGENT_250  SIM_019648
# 9    AGENT_814  SIM_068401
# 10   AGENT_052  SIM_215847
# 11   AGENT_946  SIM_250155
# 12   AGENT_230  SIM_249745
# 13   AGENT_341  SIM_097143
# 14   AGENT_343  SIM_433107
# 15   AGENT_792  SIM_049832
# 16   AGENT_800  SIM_290610
# 17   AGENT_597  SIM_152836
# 18   AGENT_662  SIM_072491
# 19   AGENT_137  SIM_386116
# 20   AGENT_101  SIM_363715
# 21   AGENT_363  SIM_459393
# 22   AGENT_532  SIM_337077
# 23   AGENT_648  SIM_337615
# 24   AGENT_618  SIM_099970
# 25   AGENT_310  SIM_097991
# 26   AGENT_772  SIM_334080
# 27   AGENT_897  SIM_152474
# 28   AGENT_286  SIM_041023
# 29   AGENT_031  SIM_095052
# ..         ...         ...
# 98   AGENT_466  SIM_491196
# 99   AGENT_878  SIM_094121
# ...

# %%
out[1]
# Out:
#          AGENT      DEALER  PASS_CONDITIONS         SIM           datetime  \
# 0    AGENT_213  DEALER_043              1.0  SIM_465053  08062016 00:21:01
# 1    AGENT_572  DEALER_021              1.0  SIM_304180  08062016 00:40:42
# 2    AGENT_302  DEALER_052              1.0  SIM_015877  08062016 00:41:50
# 3    AGENT_960  DEALER_020              1.0  SIM_362661  08062016 00:41:49
# 4    AGENT_205  DEALER_065              1.0  SIM_277356  08062016 00:52:56
# 5    AGENT_157  DEALER_059              1.0  SIM_051688  08062016 00:57:43
# 6    AGENT_583  DEALER_064              1.0  SIM_294460  08062016 01:02:47
# 7    AGENT_644  DEALER_018              1.0  SIM_415582  08062016 01:05:43
# 8    AGENT_250  DEALER_036              1.0  SIM_019648  08062016 01:08:27
# 9    AGENT_814  DEALER_085              1.0  SIM_068401  08062016 01:12:32
# 10   AGENT_052  DEALER_051              1.0  SIM_215847  08062016 01:13:23
# ...

# %%
out[2]

# %%
out[3]
