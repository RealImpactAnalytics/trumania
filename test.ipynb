# %%
from src.generator import main
out = main()
# Out:
# Parameters
# Done
# Clock
# Done
# Generators
# Done
# initialise Time Generators
# Done
# Create callers
# Done
# Added atributes
# Creating social network
# Done
# Done SNA
# Mobility
# Network created
# Agent relationship created
# Done all customers
# Creating circus
# Done
# Start run

# %%
out[0].get_contents()[1]["customers"]._transient_attributes["MAIN_ACCT"]._table
# Out:
#             activity  clock   value
# 0000000000       1.0     -8  1970.0
# 0000000001       1.0    -10  1809.0
# 0000000002       1.0     -5  1980.0
# 0000000003       1.0     -3  1684.0
# 0000000004       1.0     -7  1810.0
# 0000000005       1.0    -11   990.0
# 0000000006       1.0    -11   980.0
# 0000000007       1.0     -5  1780.0
# 0000000008       1.0     -9  1815.0
# 0000000009       1.0    -11   990.0
# 0000000010       1.0     -7  1954.0
# 0000000011       1.0     -3  1819.0
# 0000000012       1.0     -2  1786.0
# 0000000013       1.0     -8  1606.0
# 0000000014       1.0     -8  1859.0
# 0000000015       1.0     -7  1909.0
# 0000000016       1.0     -8  1905.0
# 0000000017       1.0     -7  1867.0
# 0000000018       1.0    -11   980.0
# 0000000019       1.0     -9  1673.0
# 0000000020       1.0     -5  1793.0
# 0000000021       1.0    -11   980.0
# 0000000022       1.0    -11   980.0
# 0000000023       1.0     -6  1858.0
# 0000000024       1.0     -6  1759.0
# ...

# %%
out[1]
# Out:
#                A PRODUCT  DURATION   TYPE  VALUE           B  PASS_CONDITIONS  \
# 0     0000000001   VOICE      85.0  VOICE   85.0  0000000019                1
# 1     0000000025     SMS       NaN    SMS   10.0  0000000001                1
# 2     0000000029   VOICE      69.0  VOICE   69.0  0000000754                1
# 3     0000000031     SMS       NaN    SMS   10.0  0000000633                1
# 4     0000000052   VOICE      76.0  VOICE   76.0  0000000919                1
# 5     0000000086     SMS       NaN    SMS   10.0  0000000263                1
# 6     0000000087     SMS       NaN    SMS   10.0  0000000171                1
# 7     0000000091     SMS       NaN    SMS   10.0  0000000805                1
# 8     0000000093   VOICE     191.0  VOICE  191.0  0000000398                1
# 9     0000000095   VOICE      63.0  VOICE   63.0  0000000438                1
# 10    0000000100   VOICE     111.0  VOICE  111.0  0000000708                1
# ...

# %%
out[2]

# %%
out[3]
