# %%
from src.generator import main
out = main()
# Out:
# Parameters
# Done
# Clock
# Done
# Generators
# Done
# initialise Time Generators
# Done
# Create callers
# Done
# Added atributes
# Creating social network
# Done
# Done SNA
# Mobility
# Network created
# Done all customers
# Creating circus
# Done
# Start run

# %%
out[0].get_contents()[1]["customers"]._transient_attributes["CELL"]._table
# Out:
#             activity  clock      value
# 0000000000       1.0     13  CELL_0013
# 0000000001       1.0     12  CELL_0052
# 0000000002       1.0     23  CELL_0096
# 0000000003       1.0      9  CELL_0052
# 0000000004       1.0      9  CELL_0092
# 0000000005       1.0     15  CELL_0039
# 0000000006       1.0      0  CELL_0072
# 0000000007       1.0      8  CELL_0029
# 0000000008       1.0      7  CELL_0010
# 0000000009       1.0      4  CELL_0026
# 0000000010       1.0     17  CELL_0060
# 0000000011       1.0      0  CELL_0024
# 0000000012       1.0      8  CELL_0011
# 0000000013       1.0      9  CELL_0048
# 0000000014       1.0      8  CELL_0078
# 0000000015       1.0     17  CELL_0085
# 0000000016       1.0     17  CELL_0099
# 0000000017       1.0      8  CELL_0080
# 0000000018       1.0      7  CELL_0009
# 0000000019       1.0      7  CELL_0099
# 0000000020       1.0      9  CELL_0090
# 0000000021       1.0     17  CELL_0095
# 0000000022       1.0     11  CELL_0012
# ...

# %%
out[1]
# Out:
#                 A           B           datetime       A_NUMBER  \
# 0      0000000001  0000008028  08062016 00:35:13  0032478242305
# 1      0000000025  0000003692  08062016 00:46:34  0032478183739
# 2      0000000029  0000006668  08062016 00:08:18  0032475314390
# 3      0000000031  0000001405  08062016 00:52:01  0032477951929
# 4      0000000052  0000005653  08062016 00:02:51  0032479896864
# 5      0000000086  0000002315  08062016 00:46:39  0032477423637
# 6      0000000087  0000008202  08062016 00:09:15  0032476652753
# 7      0000000091  0000005439  08062016 00:48:27  0032472634511
# 8      0000000093  0000007084  08062016 00:00:32  0032478242348
# 9      0000000095  0000003528  08062016 00:03:35  0032478280902
# 10     0000000100  0000001107  08062016 00:11:16  0032479156981
# 11     0000000101  0000009713  08062016 00:36:24  0032472687201
# 12     0000000111  0000006055  08062016 00:41:46  0032476783177
# 13     0000000120  0000003161  08062016 00:21:30  0032476847240
# ...

# %%
out[2]
# Out:
#                A        new           datetime
# 0     0000000052  CELL_0014  08062016 00:42:08
# 1     0000000205  CELL_0098  08062016 00:39:03
# 2     0000000213  CELL_0041  08062016 00:10:23
# 3     0000000230  CELL_0082  08062016 00:50:46
# 4     0000000302  CELL_0024  08062016 00:11:23
# 5     0000000572  CELL_0037  08062016 00:20:05
# 6     0000000583  CELL_0059  08062016 00:19:59
# 7     0000000792  CELL_0075  08062016 00:00:07
# 8     0000000814  CELL_0008  08062016 00:08:07
# 9     0000000960  CELL_0066  08062016 00:42:45
# 10    0000001105  CELL_0023  08062016 00:28:33
# 11    0000001128  CELL_0042  08062016 00:17:12
# 12    0000001159  CELL_0016  08062016 00:24:00
# 13    0000001280  CELL_0075  08062016 00:57:00
# 14    0000001289  CELL_0095  08062016 00:10:19
# 15    0000001370  CELL_0030  08062016 00:40:16
# 16    0000001410  CELL_0034  08062016 00:00:55
# 17    0000001458  CELL_0082  08062016 00:51:36
# 18    0000001466  CELL_0072  08062016 00:17:07
# ...

# %%
out[3]
# Out:
# {'caller SNA graph creation': 0.3999999999999999,
#  'caller attribute creation': 1.46,
#  'caller creation (solo)': 0.020000000000000018,
#  'callers creation (full)': 1.9099999999999997,
#  'circus creation': 0.0,
#  'clocks': 0.0,
#  'generators': 0.039999999999999925,
#  'init generators': 0.0,
#  'mobility attribute creation': 0.040000000000000036,
#  'mobility graph creation': 1.4000000000000004,
#  'one run (average)': 1.874,
#  'parameters': 0.0,
#  'runs (all)': 18.740000000000002}
