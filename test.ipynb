# %%
from src.generator import main
out = main()
# Out:
# Parameters
# Done
# Clock
# Done
# Generators
# Done
# initialise Time Generators
# Done
# Create callers
# Done
# Added atributes
# Creating social network
# Done
# Done SNA
# Mobility
# Network created
# Agent relationship created
# Done all customers
# Creating circus
# Done
# Start run

# %%
out[0].get_contents()[1]["customers"]._transient_attributes["MAIN_ACCT"]._table

# %%
out[1]
# Out:
#                  A PRODUCT  DURATION   TYPE  VALUE           B  \
# 0       0000000001   VOICE      85.0  VOICE   85.0  0000056095
# 1       0000000025     SMS       NaN    SMS   10.0  0000006462
# 2       0000000029   VOICE      69.0  VOICE   69.0  0000061545
# 3       0000000031     SMS       NaN    SMS   10.0  0000097596
# 4       0000000052   VOICE      76.0  VOICE   76.0  0000076346
# 5       0000000086     SMS       NaN    SMS   10.0  0000053014
# 6       0000000087     SMS       NaN    SMS   10.0  0000071777
# 7       0000000091     SMS       NaN    SMS   10.0  0000015097
# 8       0000000093   VOICE     191.0  VOICE  191.0  0000066643
# 9       0000000095   VOICE      63.0  VOICE   63.0  0000041683
# 10      0000000100   VOICE     111.0  VOICE  111.0  0000034759
# 11      0000000101   VOICE      52.0  VOICE   52.0  0000049491
# 12      0000000111   VOICE     235.0  VOICE  235.0  0000047239
# 13      0000000120   VOICE     184.0  VOICE  184.0  0000023996
# ...

# %%
out[2]

# %%
out[3]
