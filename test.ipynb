# %%
from src.clock import TimeProfiler, Clock
import pandas as pd
from datetime import timedelta, datetime

prof = pd.Series([1.,2.,1.,1.,1.,1.,1.],
    index=[timedelta(hours=23,minutes=59,seconds=59),
                       timedelta(days=1,hours=23,minutes=59,seconds=59),
                       timedelta(days=2,hours=23,minutes=59,seconds=59),
                       timedelta(days=3,hours=23,minutes=59,seconds=59),
                       timedelta(days=4,hours=23,minutes=59,seconds=59),
                       timedelta(days=5,hours=23,minutes=59,seconds=59),
                       timedelta(days=6,hours=23,minutes=59,seconds=59)])

x = TimeProfiler(3600,prof,seed=123456)

# %%
cl = Clock(datetime(year=2016,month=6,day=8),step=3600,format_for_out="%d%m%Y %H:%M:%S",seed=123456)

# %%
x.initialise(cl)

# %%
y = x.get_profile()

# %%
x.increment()

# %%
y2 = x.get_profile()

# %%
w = pd.Series([10,14,8,18,3],index=range(1,6))
x.get_next_steps(w)

# %%
x.get_next_steps(w)

# %%
from src.generator import main
out = main()
# Out:
# Start run

# %%
out[0].get_contents()[1]["customers"]._table
# Out:
#    ID    activity  clock         MSISDN
# 0   0   11.198047      1  0032478721241
# 1   1  170.408164      0  0032478242305
# 2   2   12.858978      1  0032473942735
# 3   3   66.598996      1  0032476053706
# 4   4   14.829093     11  0032475285531
# 5   5   14.070650      8  0032477478674
# 6   6   16.491923      2  0032479328653
# 7   7   46.111664      2  0032476081367
# 8   8   11.156873      6  0032476504058
# 9   9   19.205425      5  0032479599658

# %%
out[1]
# Out:
#      A  B           datetime       A_NUMBER       B_NUMBER
# 0    1  4  08062016 00:35:13  0032478242305  0032475285531
# 1    0  7  08062016 01:46:34  0032478721241  0032475285531
# 2    1  4  08062016 01:08:18  0032478242305  0032476081367
# 3    8  7  08062016 01:52:01  0032476504058  0032476081367
# 4    1  4  08062016 02:02:51  0032478242305  0032475285531
# 5    3  4  08062016 02:46:39  0032476053706  0032475285531
# 6    7  8  08062016 02:09:15  0032476081367  0032476504058
# 7    1  6  08062016 03:48:27  0032478242305  0032478721241
# 8    2  8  08062016 03:00:32  0032473942735  0032473942735
# 9    3  4  08062016 03:03:35  0032476053706  0032475285531
# 10   4  2  08062016 03:11:16  0032475285531  0032479328653
# 11   5  0  08062016 03:36:24  0032477478674  0032476504058
# 12   7  8  08062016 03:41:46  0032476081367  0032476504058
# 13   1  6  08062016 04:21:30  0032478242305  0032478721241
# 14   3  0  08062016 04:55:40  0032476053706  0032478242305
# 15   6  1  08062016 04:43:00  0032479328653  0032479328653
# 16   7  8  08062016 04:16:43  0032476081367  0032479328653
# 17   9  6  08062016 04:05:03  0032479599658  0032476504058
