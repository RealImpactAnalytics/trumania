# %%
from src.generator import main
out = main()
# Out:
# Parameters
# Done
# Clock
# Done
# Generators
# Done
# initialise Time Generators
# Done
# Create callers
# Done
# Added atributes
# Mobility
# Network created
# Done all customers
# Creating circus
# Done
# Start run
# iteration 0 on 10
# iteration 1 on 10
# iteration 2 on 10
# iteration 3 on 10
# iteration 4 on 10
# iteration 5 on 10
# iteration 6 on 10
# iteration 7 on 10
# iteration 8 on 10
# iteration 9 on 10

# %%
out[0].get_contents()[1]["customers"]._transient_attributes["SIM"].stock()._table
# Out:
#          AGENT        ITEM
# 0    AGENT_157  SIM_358355
# 1    AGENT_205  SIM_308380
# 2    AGENT_213  SIM_017139
# 3    AGENT_302  SIM_454751
# 4    AGENT_572  SIM_058722
# 5    AGENT_960  SIM_285543
# 6    AGENT_052  SIM_257817
# 7    AGENT_230  SIM_023178
# 8    AGENT_250  SIM_220748
# 9    AGENT_341  SIM_048671
# 10   AGENT_343  SIM_445485
# 11   AGENT_583  SIM_100064
# 12   AGENT_644  SIM_071217
# 13   AGENT_792  SIM_288544
# 14   AGENT_814  SIM_429448
# 15   AGENT_946  SIM_248638
# 16   AGENT_031  SIM_091518
# 17   AGENT_101  SIM_287707
# 18   AGENT_137  SIM_152616
# 19   AGENT_286  SIM_326358
# 20   AGENT_310  SIM_151695
# 21   AGENT_363  SIM_339218
# 22   AGENT_662  SIM_339218
# 23   AGENT_518  SIM_469702
# 24   AGENT_532  SIM_103056
# 25   AGENT_597  SIM_170297
# 26   AGENT_618  SIM_092457
# 27   AGENT_648  SIM_042877
# 28   AGENT_678  SIM_330971
# 29   AGENT_696  SIM_070006
# ..         ...         ...
# 97   AGENT_772  SIM_118029
# 98   AGENT_878  SIM_473660
# ...

# %%
out[1]
# Out:
#          AGENT      DEALER         SIM  PASS_CONDITIONS           datetime
# 0    AGENT_157  DEALER_034  SIM_358355                1  08062016 00:35:13
# 1    AGENT_205  DEALER_014  SIM_308380                1  08062016 00:46:34
# 2    AGENT_213  DEALER_060  SIM_017139                1  08062016 00:08:18
# 3    AGENT_302  DEALER_007  SIM_454751                1  08062016 00:52:01
# 4    AGENT_572  DEALER_083  SIM_058722                1  08062016 00:02:51
# 5    AGENT_960  DEALER_071  SIM_285543                1  08062016 00:46:39
# 6    AGENT_052  DEALER_060  SIM_257817                1  08062016 01:09:15
# 7    AGENT_230  DEALER_015  SIM_023178                1  08062016 01:48:27
# 8    AGENT_250  DEALER_036  SIM_220748                1  08062016 01:00:32
# 9    AGENT_341  DEALER_091  SIM_048671                1  08062016 01:03:35
# 10   AGENT_343  DEALER_070  SIM_445485                1  08062016 01:11:16
# ...

# %%
out[2]

# %%
out[3]
